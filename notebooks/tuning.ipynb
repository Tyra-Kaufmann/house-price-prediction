# %% [markdown]
# # Finding the Best Model

# %%
# !pip install optuna

import optuna
import pandas as pd
import pickle

from pgeocode import Nominatim
from sklearn.compose import ColumnTransformer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from xgboost import XGBRegressor
# Out:
# Collecting optuna
#   Obtaining dependency information for optuna from https://files.pythonhosted.org/packages/5c/5e/068798a8c7087863e7772e9363a880ab13fe55a5a7ede8ec42fab8a1acbb/optuna-4.4.0-py3-none-any.whl.metadata
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\tyrak\anaconda3\lib\site-packages (from optuna) (1.13.3)
# Collecting colorlog (from optuna)
#   Obtaining dependency information for colorlog from https://files.pythonhosted.org/packages/e3/51/9b208e85196941db2f0654ad0357ca6388ab3ed67efdbfc799f35d1f83aa/colorlog-6.9.0-py3-none-any.whl.metadata
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\tyrak\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tyrak\anaconda3\lib\site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\tyrak\anaconda3\lib\site-packages (from optuna) (2.0.37)
# Requirement already satisfied: tqdm in c:\users\tyrak\anaconda3\lib\site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in c:\users\tyrak\anaconda3\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in c:\users\tyrak\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: typing-extensions>=4 in c:\users\tyrak\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\tyrak\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\users\tyrak\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\tyrak\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ---------------------------------------- 0.0/395.9 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/395.9 kB 640.0 kB/s eta 0:00:01
#    ------ -------------------------------- 61.4/395.9 kB 812.7 kB/s eta 0:00:01
#    --------- ---------------------------- 102.4/395.9 kB 980.4 kB/s eta 0:00:01
#    -------------- ----------------------- 153.6/395.9 kB 913.1 kB/s eta 0:00:01
#    ------------------- ------------------ 204.8/395.9 kB 958.4 kB/s eta 0:00:01
#    ---------------------- --------------- 235.5/395.9 kB 901.1 kB/s eta 0:00:01
#    --------------------------- ---------- 286.7/395.9 kB 930.9 kB/s eta 0:00:01
#    ------------------------------ ------- 317.4/395.9 kB 936.6 kB/s eta 0:00:01
#    -------------------------------------  389.1/395.9 kB 969.0 kB/s eta 0:00:01
#    -------------------------------------- 395.9/395.9 kB 947.7 kB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.9.0 optuna-4.4.0

# %%
df = pd.read_csv('../data/housing_cleaned.csv')

df.head()
# Out:
#       price       city  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  231300.0    Seattle         2       1.00         1180      5650     1.0
# 1  538000.0    Seattle         3       2.25         2570      7242     2.0
# 2  180000.0    Kenmore         2       1.00          770     10000     1.0
# 3  604000.0    Seattle         4       3.00         1960      5000     1.0
# 4  510000.0  Sammamish         3       2.00         1680      8080     1.0
#
#    condition  sqft_basement  pct_basement  house_age  was_renovated  \
# 0          3              0      0.000000         70              0
# 1          3            400      0.155642         74              1
# 2          3              0      0.000000         92              0
# 3          5            910      0.464286         60              0
# 4          3              0      0.000000         38              0
#
#    renovation_age  sqft_living15  sqft_lot15
# 0              70           1340        5650
# 1              34           1690        7639
# 2              92           2720        8062
# 3              60           1360        5000
# 4              38           1800        7503

# %%
X = df.drop('price', axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=X['city'],
    random_state=42,
)

# %%
binary = ['was_renovated']
categorical = ['city']
numerical = X.select_dtypes(include=['float64', 'int64']).columns.drop(binary).tolist()

preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numerical),
    ('cat', OneHotEncoder(drop='first'), categorical),
    ('bin', 'passthrough', binary)
])

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'random_state': 42
    }

    model = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', XGBRegressor(**params))
    ])

    # Use 3-fold cross-validation
    score = cross_val_score(
        model,
        X_train,
        y_train,
        scoring='neg_root_mean_squared_error',
        cv=3,
        n_jobs=-1
    )

    return -1.0 * score.mean()

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)
# Out:
# [I 2025-07-15 15:03:10,800] A new study created in memory with name: no-name-0730738e-507a-49cb-9553-22f227d88473
# [I 2025-07-15 15:03:15,961] Trial 0 finished with value: 199004.2259497925 and parameters: {'n_estimators': 1000, 'max_depth': 12, 'learning_rate': 0.1769121924539134, 'subsample': 0.9970248078473156, 'colsample_bytree': 0.8113458803248855, 'min_child_weight': 8}. Best is trial 0 with value: 199004.2259497925.
# [I 2025-07-15 15:03:22,981] Trial 1 finished with value: 199172.26735637154 and parameters: {'n_estimators': 600, 'max_depth': 12, 'learning_rate': 0.2045942140143342, 'subsample': 0.8131698224974224, 'colsample_bytree': 0.8051512342389666, 'min_child_weight': 1}. Best is trial 0 with value: 199004.2259497925.
# [I 2025-07-15 15:03:27,739] Trial 2 finished with value: 202620.6770043779 and parameters: {'n_estimators': 800, 'max_depth': 9, 'learning_rate': 0.22821650785282405, 'subsample': 0.7565497684399295, 'colsample_bytree': 0.6289480414960645, 'min_child_weight': 4}. Best is trial 0 with value: 199004.2259497925.
# [I 2025-07-15 15:03:30,544] Trial 3 finished with value: 191114.6271413057 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.0116547263418938, 'subsample': 0.8100514051644616, 'colsample_bytree': 0.6180498496064881, 'min_child_weight': 5}. Best is trial 3 with value: 191114.6271413057.
# [I 2025-07-15 15:03:32,570] Trial 4 finished with value: 191574.2566233252 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.1136195631256396, 'subsample': 0.5140186645972371, 'colsample_bytree': 0.685247355404226, 'min_child_weight': 10}. Best is trial 3 with value: 191114.6271413057.
# [I 2025-07-15 15:03:36,501] Trial 5 finished with value: 189730.16254166173 and parameters: {'n_estimators': 600, 'max_depth': 10, 'learning_rate': 0.03319028655532402, 'subsample': 0.8418967655447342, 'colsample_bytree': 0.8346681824704139, 'min_child_weight': 8}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:42,659] Trial 6 finished with value: 200322.23067015686 and parameters: {'n_estimators': 500, 'max_depth': 12, 'learning_rate': 0.16915054655583106, 'subsample': 0.5513979807281215, 'colsample_bytree': 0.5664821317334349, 'min_child_weight': 2}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:49,282] Trial 7 finished with value: 206908.90187800748 and parameters: {'n_estimators': 800, 'max_depth': 11, 'learning_rate': 0.28527884082112287, 'subsample': 0.68901592849463, 'colsample_bytree': 0.9289192386056284, 'min_child_weight': 5}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:49,795] Trial 8 finished with value: 191244.0895387029 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.2820439847187575, 'subsample': 0.9436134400882281, 'colsample_bytree': 0.8435885675878501, 'min_child_weight': 7}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:52,449] Trial 9 finished with value: 200105.05340407207 and parameters: {'n_estimators': 800, 'max_depth': 8, 'learning_rate': 0.19081227494468453, 'subsample': 0.6119488279982648, 'colsample_bytree': 0.8898538097984374, 'min_child_weight': 8}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:53,587] Trial 10 finished with value: 190983.40494309503 and parameters: {'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.01569845474192138, 'subsample': 0.8944622148243675, 'colsample_bytree': 0.9904380328105769, 'min_child_weight': 10}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:53,901] Trial 11 finished with value: 248440.8051705804 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.010948641949382653, 'subsample': 0.8945845563498149, 'colsample_bytree': 0.9515036896521172, 'min_child_weight': 10}. Best is trial 5 with value: 189730.16254166173.
# [I 2025-07-15 15:03:55,187] Trial 12 finished with value: 188750.97955525262 and parameters: {'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.07646573936485507, 'subsample': 0.8747384626425302, 'colsample_bytree': 0.997815526046986, 'min_child_weight': 9}. Best is trial 12 with value: 188750.97955525262.
# [I 2025-07-15 15:03:56,812] Trial 13 finished with value: 188106.99418405633 and parameters: {'n_estimators': 700, 'max_depth': 6, 'learning_rate': 0.08543186440062571, 'subsample': 0.8375496066487272, 'colsample_bytree': 0.7320916591788545, 'min_child_weight': 7}. Best is trial 13 with value: 188106.99418405633.
# [I 2025-07-15 15:03:59,079] Trial 14 finished with value: 190714.8427521741 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.1008549212912958, 'subsample': 0.6814310576735026, 'colsample_bytree': 0.7393208995826345, 'min_child_weight': 7}. Best is trial 13 with value: 188106.99418405633.
# [I 2025-07-15 15:04:00,543] Trial 15 finished with value: 190772.07926052428 and parameters: {'n_estimators': 700, 'max_depth': 6, 'learning_rate': 0.08364175220040183, 'subsample': 0.7643066741269824, 'colsample_bytree': 0.7281216302074122, 'min_child_weight': 6}. Best is trial 13 with value: 188106.99418405633.
# [I 2025-07-15 15:04:01,032] Trial 16 finished with value: 188882.5137376628 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.06075631383016919, 'subsample': 0.8743279044092748, 'colsample_bytree': 0.6792479091016027, 'min_child_weight': 9}. Best is trial 13 with value: 188106.99418405633.
# [I 2025-07-15 15:04:02,381] Trial 17 finished with value: 190793.9859148996 and parameters: {'n_estimators': 900, 'max_depth': 4, 'learning_rate': 0.13622797932426206, 'subsample': 0.9403651898396913, 'colsample_bytree': 0.7833207515112864, 'min_child_weight': 3}. Best is trial 13 with value: 188106.99418405633.
# [I 2025-07-15 15:04:03,649] Trial 18 finished with value: 187163.76676017884 and parameters: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.06041198693286602, 'subsample': 0.9823340530563263, 'colsample_bytree': 0.5215133136489092, 'min_child_weight': 6}. Best is trial 18 with value: 187163.76676017884.
# [I 2025-07-15 15:04:04,633] Trial 19 finished with value: 187692.23286054275 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.05091373346591535, 'subsample': 0.9963873141501041, 'colsample_bytree': 0.5160831243815777, 'min_child_weight': 6}. Best is trial 18 with value: 187163.76676017884.
# [I 2025-07-15 15:04:05,409] Trial 20 finished with value: 189652.1148247328 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1317735115607444, 'subsample': 0.9947537163212143, 'colsample_bytree': 0.5088157768651156, 'min_child_weight': 4}. Best is trial 18 with value: 187163.76676017884.
# [I 2025-07-15 15:04:06,602] Trial 21 finished with value: 187081.7896376654 and parameters: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.04917335244235625, 'subsample': 0.9487819130402928, 'colsample_bytree': 0.5131721060283253, 'min_child_weight': 6}. Best is trial 21 with value: 187081.7896376654.
# [I 2025-07-15 15:04:07,606] Trial 22 finished with value: 187072.12730090253 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0392644727808183, 'subsample': 0.9436534387455704, 'colsample_bytree': 0.5036947715909679, 'min_child_weight': 6}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:09,346] Trial 23 finished with value: 187569.03840994195 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.048319646807940396, 'subsample': 0.9415191980879445, 'colsample_bytree': 0.5630223288699788, 'min_child_weight': 6}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:10,603] Trial 24 finished with value: 191239.05468841406 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.04525603277702821, 'subsample': 0.9463061189041646, 'colsample_bytree': 0.5674449767241357, 'min_child_weight': 4}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:12,038] Trial 25 finished with value: 187074.20045745175 and parameters: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.0691392570298919, 'subsample': 0.9165862875836283, 'colsample_bytree': 0.5340216579061501, 'min_child_weight': 5}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:13,255] Trial 26 finished with value: 190361.54758404606 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.11408721243411055, 'subsample': 0.9066115030248482, 'colsample_bytree': 0.6174004388245768, 'min_child_weight': 5}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:13,863] Trial 27 finished with value: 189518.9193317528 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.03469648342649983, 'subsample': 0.7087139310853102, 'colsample_bytree': 0.5488144080511825, 'min_child_weight': 3}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:15,445] Trial 28 finished with value: 188513.61557772537 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.07025686445189755, 'subsample': 0.9229843556159775, 'colsample_bytree': 0.5978077959159253, 'min_child_weight': 5}. Best is trial 22 with value: 187072.12730090253.
# [I 2025-07-15 15:04:18,329] Trial 29 finished with value: 193095.9742424715 and parameters: {'n_estimators': 700, 'max_depth': 10, 'learning_rate': 0.09587311160955758, 'subsample': 0.9692820785992908, 'colsample_bytree': 0.6492075584083336, 'min_child_weight': 7}. Best is trial 22 with value: 187072.12730090253.

# %%
study.best_params
# Out:
# {'n_estimators': 400,
#  'max_depth': 7,
#  'learning_rate': 0.0392644727808183,
#  'subsample': 0.9436534387455704,
#  'colsample_bytree': 0.5036947715909679,
#  'min_child_weight': 6}

# %%
best_params = study.best_params

best_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(**best_params))
])

best_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'sqft_living', 'sqft_lot',
#                                                    'floors', 'condition',
#                                                    'sqft_basement',
#                                                    'pct_basement', 'house_age',
#                                                    'renovation_age',
#                                                    'sqft_living15',
#                                                    'sqft_lot15']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['city']),
#                                                  ('bin', 'passthrough',
#                                                   ['was_renovated'])])),
#                 ('regressor',...
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None,
#                               learning_rate=0.0392644727808183, max_bin=None,
#                               max_cat_threshold=None, max_cat_to_onehot=None,
#                               max_delta_step=None, max_depth=7, max_leaves=None,
#                               min_child_weight=6, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=400, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
y_pred_train = best_pipeline.predict(X_train)
y_pred_test = best_pipeline.predict(X_test)

# %%
print(f'Train RMSE: {root_mean_squared_error(y_train, y_pred_train):,.0f}')
print(f'Test RMSE: {root_mean_squared_error(y_test, y_pred_test):,.0f}')
# Out:
# Train RMSE: 106,192
# Test RMSE: 164,350

# %%
with open('../api/models/best_optuna_model.pkl', 'wb') as f:
    pickle.dump(best_pipeline, f)
